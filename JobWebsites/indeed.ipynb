# %%
import requests
from bs4 import BeautifulSoup
import datetime
import time
import pandas as pd
import numpy as np

# %%
# example url
# https://www.indeed.com/jobs?q=swe+intern&l=Seattle%2C+WA&fromage=3

#### Fields ####
# query : q
# salary estimate(included in query params): $35,000
# date posted: fromage : int (day)
# jt: job type (jt=fulltime, parttime, contract, temporary, internship)
# location : l (l=Seattle,+WA)
# distance/ within _ miles: radius=(5,10,15,25,50,100)
# experience level: explvl=entry_level, senior_level, mid_level

# %%
'''
A python crawler that uses BeautifulSoup4 and requests module to access
Indeed job posts based on certain query parameters, returns a list of job posts
with the format of :
{
    "job_url": job_url,
    "job_title": job_title,
    "company_url": company_url,
    "company_name": company_name,
    "job description": job_description,
    "date": date,
    'new': new
}
'''
class IndeedAPI:
    
    currentTime = datetime.datetime.now()
    source_url = "https://www.indeed.com"
    # Indeed website base url to build on 
    base_url = "https://www.indeed.com/"
    
    query_params = {
    'q':None, 
    'fromage':None, 
    'jt': ['fulltime', 'parttime', 'contract', 'temporary', 'internship'], 
    'radius': None, 
    'salary_estimate': None,
    'l': None,
    'explvl': ['entry_level', 'senior_level', 'mid_level']
    }
    

    # Initialize class
    def __init__(self):
        self.queries =  {}
    

    # Lets client know the query parameter meaning and options
    def listAllQueryOptions(self):
        print(
        '\tq -- representing \"job query parameters\" \n\
        fromage -- \"Days since job posted\" \n\
        jt -- \"job type\" (ex: fulltime, parttime, contract, temporary, internship) \n\
        radius -- \"distance within miles\" \n\
        salary_estimate --  \"Estimated salary\" (included in query parameters)\n\
        l -- \"location\" (ex: Seattle,+ WA or Seattle+WA) \n\
        explvl: \"experience level\" (ex: entry_level, senior_level, mid_level)'
        )


    # Validate user input of query parameter key value pair
    def keyValueValidation(self, key, value):
        if key not in self.query_params:
            print(f"{key} is not in the mandated query params, which are {self.query_params.keys()}")
            return None, None
        else:
            # key is in query parameters
            res = self.query_params[key]
            if res != None:
                # needs to check if the value is allowed
                if value not in res:
                    print(f"{value} is not a valid option for {key}. The valid options are {res}")
                    return None, None
                else:
                    return key, value
            
            # if res is None, clean value before returning
            return key, value.strip()



    # Cleans all the dates fetched from the website into a date string
    def cleanDate(self, date):
        # EX: ['Active 5 days ago', '30+ days ago', '11 days ago', 'Today', '2 days ago'] -> '2021-4-30'
        date = date.replace('Active', '')
        
        if 'days ago' in date:
            date = date.replace('days ago', '')
        if 'Today' in date:
            date = '1'
        
        days = int(date.strip().replace('+',''))

        modified_date = self.currentTime - datetime.timedelta(days = days)
        return f"{modified_date.year}-{modified_date.month}-{modified_date.day}"



    # add queries to the dictionary "queries" that stores all query parameter and values as key-value pair
    def addQueries(self, key, value):
        key, value = self.keyValueValidation(key,value)
        if key != None and  value != None:
            self.queries[key] = value


    # Build up the search url from the base_url
    def constructSearchJobUrl(self):
        # EX:
        # https://www.indeed.com/jobs?q=Software+Engineer+Intern&l=Bellevue%2C+WA
        QUERY_ENDING = "&"
        self.base_url += "jobs?"
        # loop over the queries dictionary
        for k, v in self.queries.items():
            if k == "q":
                self.base_url = self.base_url + f"{k}=" + "+".join(v.split(" ")) + QUERY_ENDING
            elif k != "l":
                self.base_url = self.base_url + f"{k}={v}" + QUERY_ENDING
        
        if "l" in self.queries:
            self.base_url = self.base_url + "l=" + "+".join(self.queries['l'].replace(" ","").split(","))
        else:
            self.base_url = self.base_url + "l="


    # Fetch data from  a list of our targeted Beautiful Soup instance
    def getJobPost(self, foundSoup):        
        NEW_FLAG = 'new'
        
        try:
            job_url = self.source_url + foundSoup.find("h2", "title").a['href']
        except:
            job_url = None
        try:
            job_title = foundSoup.find("h2", "title").get_text().strip()
            if NEW_FLAG in job_title:
                new = True
            else:
                new = False
            job_title = job_title.replace(NEW_FLAG, '').strip()
        except:
            job_title = None
        try:
            company_url = self.source_url + foundSoup.find("span", "company").a['href']
        except:
            company_url = None
        
        try:
            company_name = foundSoup.find("span", "company").get_text().strip()
        except:
            company_name = None
        
        
        try:
            job_description = foundSoup.find("div", "summary").li.get_text()
        except:
            job_description = None
        

        try:
            date = self.cleanDate(foundSoup.find("span", "date-a11y").get_text())
        except:
            date = None


        return {
            "job_url": job_url,
            "job_title": job_title,
            "company_url": company_url,
            "company_name": company_name,
            "job description": job_description,
            "date": date,
            'new': new
        }

    # Use the formatted url to make a GET request, and use helper method getJobPost to parse
    # the data. If http status code doesn't return 200, then we abort, and print out a message.
    def makeRequestToFirstPage(self):    
        res = requests.get(self.base_url)
        if res.status_code != 200:
            print('Http request has error... abort')
            return None
        else:
            res_text = res.text
            res_soup = BeautifulSoup(res_text, "html.parser")
            allJobPosts = res_soup.find_all("div", "jobsearch-SerpJobCard")
            res = list(map(lambda x: self.getJobPost(x), allJobPosts))
            print(f"First page got {len(res)} job posts")
            return res


    def makeRequestToNextPage(self):
        restJobs = []
        TRAVERSE_ADDON = "&start="
        TRAVERSE_UNIT = 10
        TRAVERSE_NUMBER = 10
        # 6 pages
        
        while TRAVERSE_NUMBER <= 60: 
            print(f"Trying to access {self.base_url + TRAVERSE_ADDON + str(TRAVERSE_NUMBER)}")
            res = requests.get(self.base_url + TRAVERSE_ADDON + str(TRAVERSE_NUMBER)) 
            if res.status_code != 200:
                print('Http request has error... abort')
                return
            else:
                res_text = res.text
                res_soup = BeautifulSoup(res_text, "html.parser")
                allJobPosts = res_soup.find_all("div", "jobsearch-SerpJobCard")
                restJobs += list(map(lambda x: self.getJobPost(x), allJobPosts))
            
            time.sleep(1)
            TRAVERSE_NUMBER += TRAVERSE_UNIT
        
        print("Page traversal got : ", len(restJobs), "jobs")
        return restJobs
    

    def makeRequest(self):
        total = self.makeRequestToFirstPage() + self.makeRequestToNextPage()
        print(f"Got total of {len(total)} of job posts")
        return total

# %%
# Indeed API usage
indeed = IndeedAPI()
indeed.addQueries('q','software engineer intern')
indeed.addQueries('l', 'seattle, wa')
indeed.constructSearchJobUrl()

jobs = indeed.makeRequest()
jobs
# Out:
# First page got 15 job posts
# Trying to access https://www.indeed.com/jobs?q=software+engineer+intern&l=seattle+wa&start=10
# Trying to access https://www.indeed.com/jobs?q=software+engineer+intern&l=seattle+wa&start=20
# Trying to access https://www.indeed.com/jobs?q=software+engineer+intern&l=seattle+wa&start=30
# Trying to access https://www.indeed.com/jobs?q=software+engineer+intern&l=seattle+wa&start=40
# Trying to access https://www.indeed.com/jobs?q=software+engineer+intern&l=seattle+wa&start=50
# Trying to access https://www.indeed.com/jobs?q=software+engineer+intern&l=seattle+wa&start=60
# Page traversal got :  80 jobs
# Got total of 95 of job posts
# clk?jk=740fcfa18e65e970&fccid=2ac0dbed95f0e3bf&vjs=3',
#   'job_title': 'Platform Cloud (Media/Infrastructure) Services Engineering I...',
#   'company_url': None,
#   'company_name': 'VIZIO, Inc.',
#   'job description': 'Put comments in code as appropriate, and produces external documentation for more complex software components.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=aca2e6c965808bd7&fccid=aef928e89977f7f0&vjs=3',
#   'job_title': 'Site Reliability Engineering Intern (Remote - Summer 2021)',
#   'company_url': 'https://www.indeed.com/cmp/Splunk',
#   'company_name': 'Splunk',
#   'job description': 'You will design, develop, and test software systems.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=90b6c1c0c40dac70&fccid=da3c7fed78dd1607&vjs=3',
#   'job_title': 'Back End, Full Stack Engineering Intern',
#   'company_url': 'https://www.indeed.com/cmp/Samsung-Electronics-9',
#   'company_name': 'Samsung Electronics',
#   'job description': 'Work with great Engineers and solve difficult problems aimed at making the Customer experience seamless.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=1fbd8baca8e1e296&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Full Time Opportunities for PhD Students & Recent Graduates...',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Software engineers (SWEs) work with teammates to solve problems and build innovative software solutions.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=b02c837c6961ff26&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Precision Health Strategy',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Participation in the Research Internship Program requires that you are physically located in the United States or Canada for the duration of the internship.',
#   'date': '2021-4-27',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=3b9d336768ceba02&fccid=6416f1dd441966d8&vjs=3',
#   'job_title': 'Business Development Internship',
#   'company_url': None,
#   'company_name': 'Zeevo Group',
#   'job description': 'By leveraging finance, technology, and operational experience, and using tested and proven program and project management techniques, we help our clients move…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=7addb8dd3c626285&fccid=6416f1dd441966d8&vjs=3',
#   'job_title': 'Dashboard & Analytics Internship',
#   'company_url': None,
#   'company_name': 'Zeevo Group',
#   'job description': 'You start by building a thorough understanding of business processes and the underlying systems and data structures.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=7addb8dd3c626285&fccid=6416f1dd441966d8&vjs=3',
#   'job_title': 'Dashboard & Analytics Internship',
#   'company_url': None,
#   'company_name': 'Zeevo Group',
#   'job description': 'You start by building a thorough understanding of business processes and the underlying systems and data structures.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=d7f163d95c0f683f&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Energy Sustainability Monitoring',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'At Azure for Industries, interns pursue projects alongside fellow doctoral candidates and fulltime engineers.',
#   'date': '2021-4-27',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=4113c55189ca42c0&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Genomics',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Microsoft Healthcare is an interdisciplinary team of scientists, engineers, and medical doctors who endeavor to develop the computational tools needed for…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=79e7ebb6f11718cc&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Quantum Programming',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Interns put inquiry and theory into practice.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=7600adb7b0a9a099&fccid=729eb000fb24b6d7&vjs=3',
#   'job_title': 'Image and Signal Processing Software Intern',
#   'company_url': 'https://www.indeed.com/cmp/Fluke',
#   'company_name': 'Fluke',
#   'job description': 'Implement software/firmware on one or more platforms using appropriate development frameworks.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=583378acec5e4a6f&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Office of Applied Research',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Must have at least 1 year of experience in conducting research, writing peer-reviewed publications and software development.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=f92d61233e712ad5&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Genomic and Multiomic Modeling',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Participation in the Research Internship Program requires that you are physically located in the United States or Canada for the duration of the internship.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=a308bc972848b23f&fccid=6416f1dd441966d8&vjs=3',
#   'job_title': 'Technology Consultant Internship',
#   'company_url': None,
#   'company_name': 'Zeevo Group',
#   'job description': 'By leveraging finance, technology, and operational experience, and using tested and proven program and project management techniques, we help our clients move…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=9fbb2ccc69f85710&fccid=1639254ea84748b5&vjs=3',
#   'job_title': 'Research Intern, Vision Science and Computational Imaging (P...',
#   'company_url': 'https://www.indeed.com/cmp/Facebook',
#   'company_name': 'Facebook',
#   'job description': 'Our internships are sixteen (16) to twenty four (24) weeks long and we have various start dates throughout the year.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=d400346ce9cd4e07&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Computer Vision',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Strong algorithmic problem solving and software development skills (C/C++, Python, etc.).',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=4113c55189ca42c0&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Genomics',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Microsoft Healthcare is an interdisciplinary team of scientists, engineers, and medical doctors who endeavor to develop the computational tools needed for…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=79e7ebb6f11718cc&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Quantum Programming',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Interns put inquiry and theory into practice.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=7600adb7b0a9a099&fccid=729eb000fb24b6d7&vjs=3',
#   'job_title': 'Image and Signal Processing Software Intern',
#   'company_url': 'https://www.indeed.com/cmp/Fluke',
#   'company_name': 'Fluke',
#   'job description': 'Implement software/firmware on one or more platforms using appropriate development frameworks.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=583378acec5e4a6f&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Office of Applied Research',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Must have at least 1 year of experience in conducting research, writing peer-reviewed publications and software development.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=f92d61233e712ad5&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Genomic and Multiomic Modeling',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Participation in the Research Internship Program requires that you are physically located in the United States or Canada for the duration of the internship.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=a308bc972848b23f&fccid=6416f1dd441966d8&vjs=3',
#   'job_title': 'Technology Consultant Internship',
#   'company_url': None,
#   'company_name': 'Zeevo Group',
#   'job description': 'By leveraging finance, technology, and operational experience, and using tested and proven program and project management techniques, we help our clients move…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=9fbb2ccc69f85710&fccid=1639254ea84748b5&vjs=3',
#   'job_title': 'Research Intern, Vision Science and Computational Imaging (P...',
#   'company_url': 'https://www.indeed.com/cmp/Facebook',
#   'company_name': 'Facebook',
#   'job description': 'Our internships are sixteen (16) to twenty four (24) weeks long and we have various start dates throughout the year.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=d400346ce9cd4e07&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Computer Vision',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Strong algorithmic problem solving and software development skills (C/C++, Python, etc.).',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=dce59547531eddf5&fccid=da3c7fed78dd1607&vjs=3',
#   'job_title': 'E-Commerce Back End Product Management Intern, Summer 2021',
#   'company_url': 'https://www.indeed.com/cmp/Samsung-Electronics-9',
#   'company_name': 'Samsung Electronics',
#   'job description': 'Work with development and quality assurance engineers to build and ship the value-driven features.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=7aa8e241b1e6825b&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Mobility, Networking, & IoT',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'We build proof-of-concept systems, engage with academia, publish scientific papers, publish software for the research community, and transfer cutting-edge…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=3a0818d6794c235d&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Full Time Opportunities for PhD Students - Cleared Software...',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Software engineers (SWEs) work with teammates to solve problems and build innovative software solutions.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=b197c4471ede2287&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Biomedical Image Reconstruction',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'The research intern will collaborate with both internal Microsoft engineers and scientists and external partners at premier academic medical centers to:',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=fec05cea092c9496&fccid=6416f1dd441966d8&vjs=3',
#   'job_title': 'Digital Marketing/Communications Internship',
#   'company_url': None,
#   'company_name': 'Zeevo Group',
#   'job description': 'Use web analytics software to monitor the performance of our website and make recommendations for improvement.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=c8ec2c5b96a11f38&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Joint MSR-Planner/Project Research Interns...',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Should be able to independently execute a research agenda and collaborate effectively with other researchers and engineers.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=d997181d149aca3b&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Applied Sciences Group',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'During this internship, you will work closely with leading researchers in computer vision, practitioners, and software engineers to generate and evaluate state…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=4113c55189ca42c0&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Genomics',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Microsoft Healthcare is an interdisciplinary team of scientists, engineers, and medical doctors who endeavor to develop the computational tools needed for…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=79e7ebb6f11718cc&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Quantum Programming',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Interns put inquiry and theory into practice.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=583378acec5e4a6f&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Office of Applied Research',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Must have at least 1 year of experience in conducting research, writing peer-reviewed publications and software development.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=7600adb7b0a9a099&fccid=729eb000fb24b6d7&vjs=3',
#   'job_title': 'Image and Signal Processing Software Intern',
#   'company_url': 'https://www.indeed.com/cmp/Fluke',
#   'company_name': 'Fluke',
#   'job description': 'Implement software/firmware on one or more platforms using appropriate development frameworks.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=f92d61233e712ad5&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Genomic and Multiomic Modeling',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Participation in the Research Internship Program requires that you are physically located in the United States or Canada for the duration of the internship.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=a308bc972848b23f&fccid=6416f1dd441966d8&vjs=3',
#   'job_title': 'Technology Consultant Internship',
#   'company_url': None,
#   'company_name': 'Zeevo Group',
#   'job description': 'By leveraging finance, technology, and operational experience, and using tested and proven program and project management techniques, we help our clients move…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=dce59547531eddf5&fccid=da3c7fed78dd1607&vjs=3',
#   'job_title': 'E-Commerce Back End Product Management Intern, Summer 2021',
#   'company_url': 'https://www.indeed.com/cmp/Samsung-Electronics-9',
#   'company_name': 'Samsung Electronics',
#   'job description': 'Work with development and quality assurance engineers to build and ship the value-driven features.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=d400346ce9cd4e07&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Computer Vision',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Strong algorithmic problem solving and software development skills (C/C++, Python, etc.).',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=9fbb2ccc69f85710&fccid=1639254ea84748b5&vjs=3',
#   'job_title': 'Research Intern, Vision Science and Computational Imaging (P...',
#   'company_url': 'https://www.indeed.com/cmp/Facebook',
#   'company_name': 'Facebook',
#   'job description': 'Our internships are sixteen (16) to twenty four (24) weeks long and we have various start dates throughout the year.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=7aa8e241b1e6825b&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Mobility, Networking, & IoT',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'We build proof-of-concept systems, engage with academia, publish scientific papers, publish software for the research community, and transfer cutting-edge…',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=3a0818d6794c235d&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Full Time Opportunities for PhD Students - Cleared Software...',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Software engineers (SWEs) work with teammates to solve problems and build innovative software solutions.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=b197c4471ede2287&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Biomedical Image Reconstruction',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'The research intern will collaborate with both internal Microsoft engineers and scientists and external partners at premier academic medical centers to:',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=fec05cea092c9496&fccid=6416f1dd441966d8&vjs=3',
#   'job_title': 'Digital Marketing/Communications Internship',
#   'company_url': None,
#   'company_name': 'Zeevo Group',
#   'job description': 'Use web analytics software to monitor the performance of our website and make recommendations for improvement.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=c8ec2c5b96a11f38&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Joint MSR-Planner/Project Research Interns...',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'Should be able to independently execute a research agenda and collaborate effectively with other researchers and engineers.',
#   'date': '2021-3-31',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=d997181d149aca3b&fccid=734cb5a01ee60f80&vjs=3',
#   'job_title': 'Research Intern - Applied Sciences Group',
#   'company_url': 'https://www.indeed.com/cmp/Microsoft',
#   'company_name': 'Microsoft',
#   'job description': 'During this internship, you will work closely with leading researchers in computer vision, practitioners, and software engineers to generate and evaluate state…',
#   'date': '2021-3-31',
#   'new': False}]

# %%
# Indeed API usage
indeed = IndeedAPI()
indeed.addQueries('q','project management')
indeed.addQueries('l', 'phoenix')
indeed.constructSearchJobUrl()

jobs = indeed.makeRequest()
jobs
# Out:
# First page got 15 job posts
# Trying to access https://www.indeed.com/jobs?q=project+management&l=phoenix&start=10
# Trying to access https://www.indeed.com/jobs?q=project+management&l=phoenix&start=20
# Trying to access https://www.indeed.com/jobs?q=project+management&l=phoenix&start=30
# Trying to access https://www.indeed.com/jobs?q=project+management&l=phoenix&start=40
# Trying to access https://www.indeed.com/jobs?q=project+management&l=phoenix&start=50
# Trying to access https://www.indeed.com/jobs?q=project+management&l=phoenix&start=60
# Page traversal got :  94 jobs
# Got total of 109 of job posts
# -Warning-Services',
#   'company_name': 'Early Warning Services',
#   'job description': 'This job requires extensive technical and project management experience.',
#   'date': '2021-4-24',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=92c2570b40a6f29a&fccid=86f58d29912aa934&vjs=3',
#   'job_title': 'Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Southwest-Metalsmiths',
#   'company_name': 'Southwest Metalsmiths',
#   'job description': 'Management responsibility generally limited to smaller less critical projects.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=614a8efeacea1d77&fccid=7a7b422618eedf69&vjs=3',
#   'job_title': 'Project Coordinator / Accounts Payable Assistant',
#   'company_url': 'https://www.indeed.com/cmp/Toll-Brothers',
#   'company_name': 'Toll Brothers',
#   'job description': 'This position requires accounts payable experience, proficiency in Microsoft Word and Excel, and good phone skills.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=5d4aa7cc4a29316f&fccid=dcca35890004801a&vjs=3',
#   'job_title': 'Regulatory Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Valleywise-Health-System',
#   'company_name': 'Valleywise Health System',
#   'job description': 'Experience with project management software is preferred.',
#   'date': '2021-4-22',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=9b3448bf5a129aea&fccid=396559778e8b6118&vjs=3',
#   'job_title': 'Clinical Project Lead',
#   'company_url': 'https://www.indeed.com/cmp/Zoll-Medical-Corporation',
#   'company_name': 'Zoll Medical Corporation',
#   'job description': 'Acts as a project manager in planning/developing/executing all educational and training events in a customer account.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=9848d498a4bdea47&fccid=2ac480f5340d3b6a&vjs=3',
#   'job_title': 'IT Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/City-of-Goodyear,-Az',
#   'company_name': 'City of Goodyear, AZ',
#   'job description': 'Review project portfolio and all active projects.',
#   'date': '2021-4-29',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/company/SR-International-Inc./jobs/IT-27bf0c35282c9952?fccid=49913477d16faf55&vjs=3',
#   'job_title': 'IT - AZDES - AZEIP -Administration: Policy and Project Manag...',
#   'company_url': 'https://www.indeed.com/cmp/Sr-International-Inc.',
#   'company_name': 'SR International Inc.',
#   'job description': 'Works with cross-function and interagency teams to develop and implement project action plans;',
#   'date': '2021-4-28',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/company/CBC-Group-Inc/jobs/New-Product-Development-0b4c8fb8602f62d0?fccid=25ae1354e0151de4&vjs=3',
#   'job_title': 'New Product Development - Associate Brand Manager',
#   'company_url': None,
#   'company_name': 'Creative Brands',
#   'job description': 'Supports management with accurate and timely reports.',
#   'date': '2021-4-29',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=6ecbb80208b070b8&fccid=8611dbb400b20e28&vjs=3',
#   'job_title': 'Project Management Admin',
#   'company_url': 'https://www.indeed.com/cmp/Trademark-Visual',
#   'company_name': 'Trademark Visual',
#   'job description': 'Experience with project management software.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=08b0ea8f33d294fa&fccid=31696df7c99497fd&vjs=3',
#   'job_title': 'Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Ticketmaster',
#   'company_name': 'Ticketmaster',
#   'job description': '2 + years of experience in technical or operational project management.',
#   'date': '2021-4-15',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=580540de7a52a30e&fccid=0126c8ee1a0b262a&vjs=3',
#   'job_title': 'Project Management Assistant',
#   'company_url': 'https://www.indeed.com/cmp/Embry-Health',
#   'company_name': 'Embry Health',
#   'job description': 'Ensure that all project materials are kept organized and accessible to appropriate staff throughout the project timeline and are properly documented and…',
#   'date': '2021-4-28',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=2d0849d75a37995a&fccid=7229dcf4f75f990a&vjs=3',
#   'job_title': 'Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Lanmor-Services,-Inc',
#   'company_name': 'Lanmor Services',
#   'job description': '2+ years of project management experience.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=464a52d4db9df435&fccid=14d1ad8dba46509e&vjs=3',
#   'job_title': 'Project Coordinator',
#   'company_url': 'https://www.indeed.com/cmp/Partner-Engineering-and-Science,-Inc',
#   'company_name': 'Partner Engineering and Science, Inc',
#   'job description': 'Maintain project files on company server and FTP site.',
#   'date': '2021-4-16',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=dde5b5e68bece870&fccid=0b80f8854d9c78ce&vjs=3',
#   'job_title': 'Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Smithgroup',
#   'company_name': 'SmithGroup',
#   'job description': 'Manage one or more projects by negotiating project scope, fees, job production and quality, fee management and collection, monitoring project accounts as well…',
#   'date': '2021-4-27',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=6b61cd6f616a7769&fccid=0114a08e7f7e79f6&vjs=3',
#   'job_title': 'Graphic Designer\xa0/ Project Manager (full time)',
#   'company_url': None,
#   'company_name': 'Epic Signs',
#   'job description': 'Work with and support the account management team providing design proofs for new and existing customer base.',
#   'date': '2021-4-29',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0BFE_X-Y4vXCnTw9Y6Oz3zYK03DlUSqmNJoXnryIK9yl2wEN2y-1LerL5e3o9hCWiKRJYq3WX0-NDuB-tCymzN8t17tTwky6ai7hQZXHs4kNOQSF4dUcuCFP1ok4aLeYLDjwvlgqTEtGT-nsS3i-bb-Os6_u5EYaU1UvCF3kM0lwBMGkoMCy_uaQ-0jv4E9jhLvVr4wjF3jHZ0yhPcWGJrYFExePsZ9HPskgTjzy3tuh_W1r_KwMQJlZg6lhCDWGXdNYV1kXpG9ocVEK9T2lK_8fJOuve3t0dFUW8svsgEDg1klLcduRyAb-7HSeSbSHLHtOzDwac-jr1hnWdnhLxATcXMIhc1dsXZYwGl9HaeKcwbSkB8RcBQSKWjWdpjOyMwbuuTLlwEG47Ffy_lRvJOLf5-eyrBkRRd9kspaWqdNdwOQV5lD5ADBoMZaQOFoh9gn2b7bNQTvCWmEpyntI468&p=10&fvj=1&vjs=3',
#   'job_title': 'Project Manager',
#   'company_url': None,
#   'company_name': 'Confidential',
#   'job description': 'Establish and maintain project schedules.',
#   'date': '2021-4-27',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN

#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=26ffdb2967ed5d08&fccid=41bb95fa731b366c&vjs=3',
#   'job_title': 'IT Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/North-American-Bancard',
#   'company_name': 'North American Bancard',
#   'job description': 'Follow a defined project management methodology, accountable for the detailed planning of steps and resources needed to meet objectives.',
#   'date': '2021-4-23',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0BLQ6hkz6GMEPsiDV6dZwFY4wMBUE_AioakCFmtqBrqGqP687vd9SjG4_hO9-D9AKq5xbCHZpV21dpYIXzGA7gzaRDvnMsyswM-9T7fywC1pNT8C0boX_1FM64rCZWim1pP2_IEK1rouUPrQzJ9nHy1AkB-ibVv5jsXN8CVbSKxaHguvFIXHusCAt7SrKt6_I0E8fKlPSNNjQBolBw7l5JDxRNZzP3suOv88Fv1cYytdCifIKQSEqYwdVCC4reVYiQxskKtMmyttNPkZACiDxGWuf6Yxse1N5XXnNGgDfx7XOZNt5xw9qVuYEn6Vkz_pgsL2uJKh43LAuFqjXqJihkbnh6r6GZhf5CqU9sU25HaZ4u5yJsz51RC5BzBU92_HRVsUdxS1tlMS0_hnkLIpcTC2xyjOORunhhwxqzmiWmTUuteHpdAglxov1lVItNoXiw-na5Vm-GuItyfbX6qGKV04KQ9proZRCGP6CwhhS9UZDAQNV98xSZ8hKlsge8l669P9UIMDDi3mnNo2dcv_4gCwQnSTBkO5kbnIdc4GC7eWWdGrAMEjFs_fqXANUMBPAU=&p=1&fvj=0&vjs=3',
#   'job_title': 'Project Management Coordinator',
#   'company_url': 'https://www.indeed.com/cmp/Pds-Tech,-Inc.',
#   'company_name': 'PDS Tech, Inc.',
#   'job description': 'You will partner with the factory operations in providing direction that ensures product is coordinated, monitored and completes the production cycle according…',
#   'date': '2021-4-27',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=ebe8d26e909f476b&fccid=d069ec01cdba4d1c&vjs=3',
#   'job_title': 'Senior Project Manager (Facilities)',
#   'company_url': 'https://www.indeed.com/cmp/Salt-River-Pima--maricopa-Indian-Community-1',
#   'company_name': 'Salt River Pima-Maricopa Indian Community',
#   'job description': 'Manages and oversees project management activities for various construction-related projects.',
#   'date': '2021-4-28',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/company/Midwest-Real-Estate-Developer/jobs/Project-Superintendent-02e815119cbe541e?fccid=dd616958bd9ddc12&vjs=3',
#   'job_title': 'Project Superintendent',
#   'company_url': None,
#   'company_name': 'Midwest Real Estate Developer',
#   'job description': 'THIS KEY POSITION WILL ASSUME JOBSITE LEADERSHIP RESPONSIBILITIES AND GUIDE THE MEANS AND METHODS OF CONSTRUCTION.',
#   'date': '2021-4-13',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=ad175c196dc62347&fccid=425bf370eee2f3e9&vjs=3',
#   'job_title': 'Assistant Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Lennar-Corporation',
#   'company_name': 'Lennar',
#   'job description': 'Assist with special projects as assigned by department head.',
#   'date': '2021-4-21',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/company/Lifetime-Windows-and-Siding/jobs/Window-Door-Project-Manager-fae61b5fd9a71e3a?fccid=67e59351906262f1&vjs=3',
#   'job_title': 'Window and Door Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Lifetime-Windows-and-Siding',
#   'company_name': 'Lifetime Windows and Siding',
#   'job description': 'Managing project punch lists for timely completion of projects.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=14dac9651ecdf7bc&fccid=798992f9a19958dc&vjs=3',
#   'job_title': 'IT Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/City-of-Mesa',
#   'company_name': 'City of Mesa, AZ',
#   'job description': 'The ideal candidate will have proven professional experience with managing software and infrastructure projects and be competent in project planning,…',
#   'date': '2021-4-9',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=f9f1323bf35a1f21&fccid=2d3940a60e8f8f02&vjs=3',
#   'job_title': 'Project Manager - Housing Department',
#   'company_url': 'https://www.indeed.com/cmp/City-of-Phoenix',
#   'company_name': 'City of Phoenix',
#   'job description': 'Work with staff, consultants, and regulatory agencies to develop the appropriate environmental mitigations for projects.',
#   'date': '2021-4-25',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=a10c53f12f6e767b&fccid=be3b11aa573faee7&vjs=3',
#   'job_title': 'Senior Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/CVS-Health',
#   'company_name': 'CVS Health',
#   'job description': 'Proven working experience in project management.',
#   'date': '2021-4-6',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=1f6b44e03dbcffcd&fccid=b45be973c9187963&vjs=3',
#   'job_title': 'Project Manager - AV',
#   'company_url': None,
#   'company_name': 'Clearwing Productions Inc',
#   'job description': 'Determine crew needs and schedule for upcoming projects.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=379afba0031fd118&fccid=86e9be6ce380173e&vjs=3',
#   'job_title': 'Project Coordinator, Electrical',
#   'company_url': 'https://www.indeed.com/cmp/Tesla',
#   'company_name': 'Tesla',
#   'job description': 'Experience with Solar PV project management is preferred.',
#   'date': '2021-4-7',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/company/INVAR-Technologies/jobs/Technical-Project-Manager-81e63f5c5df1dab1?fccid=dced411828518d26&vjs=3',
#   'job_title': 'Technical Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Invar-Technologies',
#   'company_name': 'INVAR Technologies',
#   'job description': 'Own and manage project management tool.',
#   'date': '2021-4-25',
#   'new': True},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=3d173f5c65f753b4&fccid=3e9dbf0c067ecd4d&vjs=3',
#   'job_title': 'Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Harkins-Theatres',
#   'company_name': 'Harkins Theatres',
#   'job description': 'Project management certification preferred or 5+ years of project management experience.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/rc/clk?jk=d11f2a5e841a16c0&fccid=baef04ace81a3535&vjs=3',
#   'job_title': 'Associate Project Manager - Dam Safety',
#   'company_url': 'https://www.indeed.com/cmp/Maricopa-County',
#   'company_name': 'Maricopa County, AZ',
#   'job description': 'Performs inspection and review of engineering plans for dam safety projects; monitors all aspects of a project to include the impact on other projects.',
#   'date': '2021-4-1',
#   'new': False},
#  {'job_url': 'https://www.indeed.com/company/ADOBE-ENERGY-MANAGEMENT/jobs/Project-Manager-b882cdff760bae52?fccid=2b60b5bd82931fa5&vjs=3',
#   'job_title': 'Project Manager',
#   'company_url': 'https://www.indeed.com/cmp/Adobe-Energy-Management',
#   'company_name': 'ADOBE ENERGY MANAGEMENT',
#   'job description': 'Familiar with construction and project management software programs.',
#   'date': '2021-4-14',
#   'new': False}]
